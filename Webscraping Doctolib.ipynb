# %% [markdown]
# # MODS203 Project
# ## Ryan Borhani, Mathilde Froger, Apolline Isaia, Solal Urien

# %% [markdown]
# ### Load library

# %%
import pandas as pd
import urllib.request
import re
import requests

from bs4 import BeautifulSoup as bs
from urllib.request import Request, urlopen

# %% [markdown]
# ### Make the request and extract the HTML code

# %%
hdr = {'User-Agent': 'Mozilla/6.0'}
url = 'https://www.doctolib.fr/dentiste/paris-75019'
req = Request(url,headers=hdr)
page = urlopen(req)
soup = bs(page,'html.parser')
soup
# Out:
# <!DOCTYPE html>
# <!--Looking at our code ?
# Come have a closer look, we're hiring :)
# https://careers.doctolib.fr/?origin=home-footer&amp;utm_button=footer&amp;utm_content-group=homepage&amp;utm_page-url={page-url}&amp;utm_website=doctolib_patients--><html lang="fr"><head data-country="fr" data-env="production"><meta charset="utf-8"/><meta content="authenticity_token" name="csrf-param"/>
# <meta content="wwhK7TZBq0EoXBv4scqXViCFwzKGfeTeF9hVj+e477ynD43p7S3F8hi9PNmawUBvA7qXiNiFFkYFKQTz86tVfA==" name="csrf-token"/><meta content="origin-when-cross-origin" name="referrer"/><meta content="width=device-width, initial-scale=1.0, user-scalable=0, minimum-scale=1.0, maximum-scale=1.0, , viewport-fit=cover" name="viewport"/><meta content="Trouvez rapidement un chirurgien-dentiste à Paris - Paris 19e Arrondissement ou un praticien pratiquant des actes de chirurgie dentaire et prenez rendez-vous gratuitement en ligne en quelques clics" name="description"/><meta content="app-id=fr.doctolib.www" name="google-play-app"/><meta content="app-id=925339063" name="apple-itunes-app"/><script nonce="Dwo8vMh/G5ZqWdItRerIDg==">window.platforms = {
#   reactNative: false,
#   reactNativeAppVersion: "",
#   android: false,
#   ios: false,
#   variant: "desktop"
# };</script><div data-testid="didomi"><script nonce="Dwo8vMh/G5ZqWdItRerIDg==">window.gdprAppliesGlobally = true;
# (function () {
#   function n() {
#     if (!window.frames.__cmpLocator) {
#       if (document.body && document.body.firstChild) {
#         var e = document.body;
#         var t = document.createElement("iframe");
#         t.style.display = "none";
#         t.name = "__cmpLocator";
#         t.title = "cmpLocator";
#         e.insertBefore(t, e.firstChild)
#       } else {
#         setTimeout(n, 5)
#       }
#     }
#   }
#
#   function e(e, t, n) {
#     if (typeof n !== "function") {
#       return
#     }
#     if (!window.__cmpBuffer) {
#       window.__cmpBuffer = []
#     }
#     if (e === "ping") {
#       n({gdprAppliesGlobally: window.gdprAppliesGlobally, cmpLoaded: false}, true)
#     } else {
#       window.__cmpBuffer.push({command: e, parameter: t, callback: n})
#     }
#   }
#
#   e.stub = true;
#
#   function t(r) {
#     if (!window.__cmp || window.__cmp.stub !== true) {
#       return
#     }
#     if (!r.data) {
#       return
#     }
#     var a = typeof r.data === "string";
#     var e;
#     try {
#       e = a ? JSON.parse(r.data) : r.data
#     } catch (t) {
#       return
#     }
#     if (e.__cmpCall) {
#       var o = e.__cmpCall;
#       window.__cmp(o.command, o.parameter, function (e, t) {
#         var n = {__cmpReturn: {returnValue: e, success: t, callId: o.callId}};
#         r.source.postMessage(a ? JSON.stringify(n) : n, "*")
#       })
#     }
#   }
#
#   if (typeof window.__cmp !== "function") {
#     window.__cmp = e;
#     if (window.addEventListener) {
#       window.addEventListener("message", t, false)
#     } else {
#       window.attachEvent("onmessage", t)
#     }
#   }
#   n()
# })();
# (function (e) {
#   var t = document.createElement("script");
#   t.id = "spcloader";
#   t.type = "text/javascript";
#   t.nonce = "Dwo8vMh/G5ZqWdItRerIDg==";
#   t.async = true;
#   t.src = "https://sdk.privacy-center.org/" + e + "/loader.js?target=" + document.location.hostname;
#   t.charset = "utf-8";
#   var n = document.getElementsByTagName("script")[0];
#   n.parentNode.insertBefore(t, n)
# })("df2b9f8c-760a-445f-810e-4b47a4fe41a7");</script></div><div class="js-google-analytics" data-props="{}"></div><link href="https://assets.doctolib.fr/fonts/family-roboto-300-400-500-700-montserrat-400-500-700-merriweather-300-400-700.css" media="screen" rel="stylesheet"/><link href="/icon_patient/180x180.png" rel="apple-touch-icon"/><title>Chirurgien-dentiste à Paris - Paris 19e Arrondissement 75019 : Rendez-vous par Internet sous 24h - Doctolib</title><link href="/open_search.xml" rel="search" type="application/opensearchdescription+xml"/><script nonce="Dwo8vMh/G5ZqWdItRerIDg==">
# //<![CDATA[
# window.client_time_delta = 1672919528192 - Date.now();window.dl_constants = {"AGENDA_DEFAULT_MAX_TIME":20,"AGENDA_DEFAULT_MIN_TIME":8,"AMELI_WEB_SERVICE_URL":"https://services-ps.ameli.fr/lps","APPOINTMENT_PAGINATION_SIZE":10,"ASSET_HOST":{},"AUSTRIAN_ORGANIZATION_IDS":[51869,52174],"BILLEO_BILLING_API_KEY":"xW3KPqcWLe6ARW2MnSGFs7nWLAzlv7G86KEN7qyb","BILLEO_BILLING_LOG_URL":"https://billing-client-logs.billing.doctolib.fr/live","SENTRY_BILLEO_DSN":"https://ab4f5343d97c4399bb5352f61065a64d@o38419.ingest.sentry.io/5394243","TELEHEALTH_NEW_PATIENT_DE_ID":5027,"TELEHEALTH_NEW_PATIENT_FR_ID":2657,"COUNTRIES_CONFIG_TELEHEALTH_PATIENT_AWARENESS_QUESTIONS":{"appointment":{"fr":["booking","workflow"],"de":["advice","booking","workflow"],"it":[]},"patient":{"fr":["what","who","target","conditions"],"de":["what","conditions"],"it":[]},"reimbursement":{"fr":["price","how","payment"],"de":["payment","price"],"it":[]}},"DEBUG_FLAKY_LOGS":null,"DATA_SCIENCE_PUBLIC_KEY":"-----BEGIN PUBLIC KEY-----\\ngQIDAQAB\n-----END PUBLIC KEY-----","BASE_DATA_SCIENCE_API_URL":"https://api.datascience.doctolibdata.com/","DOCTOLIB_RELEASE":"doctolib@7f47869e9474ee4646403bbcb4431aa875188456-06f1e32ee3cb3a2d","PRODUCT_LINE_CONFIG":[{"key":"fr-gp","description":"General practitioner - France","country":"fr","product":"ehr","cluster":"ehr-default","billing_framework":"billeo","paramedic_billing":"disabled","secure_messaging_type":"MSSANTE_APICRYPT","timeline_consultation_count_position":"main_group","treatment_flow":"consultation","vaccination_module_country":"fr","import":{"flow":"gp"}},{"key":"de-gp","description":"General practitioner - Germany","country":"de","product":"ehr","cluster":"ehr-default","billing_framework":"kbv-and-de-private","paramedic_billing":"disabled","secure_messaging_type":"KIM","timeline_consultation_count_position":"sub_group","treatment_flow":"consultation","vaccination_module_country":"de","import":{"flow":"gp"}},{"key":"fr-pt","description":"Physiotherapist - France","country":"fr","product":"ehr","cluster":"ehr-physio","billing_framework":"billeo","paramedic_billing":"enabled","secure_messaging_type":"MSSANTE_APICRYPT","timeline_consultation_count_position":"main_group","treatment_flow":"care-plan","vaccination_module_country":"fr","import":{"flow":"pt"}},{"key":"fr-nurse","description":"Nurse - France (DO NOT USE in production)","country":"fr","product":"ehr","cluster":"ehr-nurse","billing_framework":"billeo","paramedic_billing":"enabled","secure_messaging_type":"MSSANTE_APICRYPT","timeline_consultation_count_position":"main_group","treatment_flow":"care-plan","vaccination_module_country":"fr","import":{"flow":"pt"}},{"key":"bms-de","description":"Booking Management System (only), Germany","country":"de","product":"bms","cluster":"bms","billing_framework":"none","paramedic_billing":"disabled","secure_messaging_type":"none","timeline_consultation_count_position":"none","treatment_flow":"none","vaccination_module_country":"none","import":{"flow":"none"}},{"key":"bms-fr","description":"Booking Management System (only), France","country":"fr","product":"bms","cluster":"bms","billing_framework":"none","paramedic_billing":"disabled","secure_messaging_type":"none","timeline_consultation_count_position":"none","treatment_flow":"none","vaccination_module_country":"none","import":{"flow":"none"}},{"key":"bms-it","description":"Booking Management System (only), Italy","country":"it","product":"bms","cluster":"bms","billing_framework":"none","paramedic_billing":"disabled","secure_messaging_type":"none","timeline_consultation_count_position":"none","treatme ...
# //]]>
# </script><link href="https://assets.doctolib.fr/webpack/css/97821-78176c08.css" media="all" rel="stylesheet"/>
# <link href="https://assets.doctolib.fr/webpack/css/53289-4876b63d.css" media="all" rel="stylesheet"/>
# <link href="https://assets.doctolib.fr/webpack/css/13761-6bba3ea5.css" media="all" rel="stylesheet"/>
# <link href="https://assets.doctolib.fr/webpack/css/85206-91ff5140.css" media="all" rel="stylesheet"/>
# <link href="https://assets.doctolib.fr/webpack/css/51298-9e567456.css" media="all" rel="stylesheet"/>
# <link href="https://assets.doctolib.fr/webpack/css/patient-desktop-c968704c.css" media="all" rel="stylesheet"/><script crossorigin="anonymous" data-lazy="no" nonce="Dwo8vMh/G5ZqWdItRerIDg==" src="https://js.sentry-cdn.com/5e227d5a9db847db9597d931c0ea0774.min.js"></script><script data-device="desktop" nonce="Dwo8vMh/G5ZqWdItRerIDg==" src="https://assets.doctolib.fr/static_webpack/sentry-c241778670c79048ce3b.js"></script><link href="/dentiste/paris-75019?page=2" rel="next"/><meta content="Chirurgien-dentiste à Paris - Paris 19e Arrondissement 75019 : Rendez-vous par Internet sous 24h - Doctolib" property="og:title"/><meta content="website" property="og:type"/><meta content="https://assets.doctolib.fr/img/logo_doctolib_square.png" property="og:image"/><meta content="https://www.doctolib.fr/" property="og:url"/><meta content="Doctolib" property="og:site_name"/><meta content="fr_FR" property="og:locale"/><meta content="Trouvez rapidement un chirurgien-dentiste à Paris - Paris 19e Arrondissement ou un praticien pratiquant des actes de chirurgie dentaire et prenez rendez-vous gratuitement en ligne en quelques clics" property="og:description"/></head><body class="search_results-online_booking_search index"><div class="flex"><div class="content-full-width application-container"><div data-props='{"pageType":"searchResultsSpecialityPlace","search_place":15321,"search_results_number_exact_match":20,"search_results_number_broad_match":0,"search_results_number_directories":0,"search_results_total":4534,"search_keyword":1,"search_type":"speciality","search_page_number":1,"speciality_id":1,"search_filtered_by_availabilities":false,"type":"area_search","events":[]}' id="datalayer"></div><div class="js-navbar" data-props='{"hide_nav_links":null,"b2b_url":"https://info.doctolib.fr?origin=home-header\u0026utm_button=header\u0026utm_content-group=search_results_page\u0026utm_page-url=https%3A%2F%2Fwww.doctolib.fr%2Fdentiste%2Fparis-75019\u0026utm_website=doctolib_patients","hasTemporaryWarning":null}'></div><div class="header_search"><div class="row-center row-padding"><div data-props='{"queryInputProps":{"defaultValue":"Chirurgien-dentiste","speciality":"dentiste"},"placeInputProps":{"defaultValue":"Paris 19e Arrondissement","place_id":"ChIJ59fvwcht5kcRcBuUaMOCCwU"}}' id="doctor_search_bar"></div></div></div><div class="sticky-search-filters-bar"><div class="js-search-filters" data-props="{&quot;search_filters_context&quot;:[{&quot;table&quot;:{&quot;label&quot;:&quot;Disponibilités&quot;,&quot;value&quot;:null,&quot;items&quot;:[{&quot;name&quot;:&quot;Aujourd'hui&quot;,&quot;id&quot;:1},{&quot;name&quot;:&quot;Dans les trois prochains jours&quot;,&quot;id&quot;:3}],&quot;order&quot;:1,&quot;enabled&quot;:true,&quot;icon&quot;:&quot;regular/calendar&quot;,&quot;input_type&quot;:&quot;int&quot;,&quot;param_name&quot;:&quot;availabilities&quot;}},{&quot;table&quot;:{&quot;label&quot;:&quot;Motif de consultation&quot;,&quot;value&quot;:null,&quot;items&quot;:[{&quot;name&quot;:&quot;Consultation vidéo - patient suivi&quot;,&quot;id&quot;:2639},{&quot;name&quot;:&quot;Consultation vidéo - nouveau patient&quot;,&quot;id&quot;:2657},{&quot;name&quot;:&quot;Première consultation dentaire&quot;,&quot;id&quot;:475},{&quot;name&quot;:&quot;Détartrage&quot;,&quot;id&quot;:476},{&quot;name&quot;:&quot;Blanchiment des dents&quot;,&quot;id&quot;:161},{&quot;name&quot;:&quot;Devis pour prothèse dentaire&quot;,&quot;id&quot;:160},{&quot;name&quot;:&quot;Urgence dentaire&quot;,&quot;id&quot;:159},{&quot;name&quot;:&quot;Enfant - Consultation dentaire&quot;,&quot;id&quot;:492},{&quot;name&quot;:&quot;Devis pour implant dentaire&quot;,&quot;id&quot;:477},{&quot;name&quot;:&quot;Consultation pour aligneurs invisibles&quot;,&quot;id&quot;:2468}],&quot;order&quot;:3,&quot;enabled&quot;:true,&quot;icon&quot;:&quot;regular/stethoscope&quot;,&quot;input_type&quot;:&quot;int&quot;,&quot;param_name&quot;:&quot;ref_visit_motive_id&quot;}},{&quot;table&quot;:{&quot;label&qu ...
# <br/>
# Vous serez amené à consulter un dentiste dans le 19e arrondissement de Paris si vous souffrez d’un mal de dent, de dents sensibles, d’une gingivite ou encore d’halitose. En effet, ce professionnel est spécialiste de la bouche, des dents, des gencives et des mâchoires. Il a suivi une formation d’odontologie de 5 à 7 ans pour pouvoir exercer.<br/>
# <br/>
# Certains dentistes dans le 19e arrondissement de Paris sont spécialisés en orthodontie. Adressez-vous à eux si vous avez besoin de corriger une malposition ou malformation bucco-dentaire. Ces consultations sont partiellement prises en charge par la Sécurité sociale. Votre mutuelle assure aussi un remboursement en fonction du contrat souscrit.<br/>
# <br/>
# <b>Comment se déroule la consultation chez un dentiste dans le 19e arrondissement de Paris ?</b><br/>
# <br/>
# Une consultation chez un dentiste dans le 19e arrondissement de Paris commence toujours par un examen approfondi de votre bouche. Le praticien vérifie l’état de vos gencives, la présence de tartre et la pousse de vos dents de sagesse. Il recherche aussi d’éventuelles caries. Selon ses observations et les informations que vous lui donnez, il dresse son diagnostic. Parfois, il est amené à réaliser une radiographie pour compléter l’examen.<br/>
# <br/>
# Parmi les actes courants réalisés par un <a href="https://www.doctolib.fr/dentiste">chirurgien-dentiste</a> figurent le détartrage, le traitement des caries, la dévitalisation d’une dent et le blanchiment. D’autres actes, comme l’implant et l’extraction dentaire, nécessitent une anesthésie locale. Vous devrez donc fixer un deuxième rendez-vous. La séance s’achève par des recommandations pour améliorer votre hygiène bucco-dentaire et éventuellement par une prescription médicale.<br/>
# <br/>
# <b>Comment prendre rendez-vous en ligne chez un dentiste dans le 19e arrondissement de Paris ?</b><br/>
# <br/>
# Près du parc des Buttes-Chaumont, de la porte de la Villette, de l'avenue Jean Jaurès ou place des Fêtes, on dénombre plus d’une centaine de dentistes dans le 19e arrondissement de Paris. D’autres exercent dans les environs, place de la République, à <a href="https://www.doctolib.fr/dentiste/paris-belleville">Belleville</a>, vers la gare de l’Est ou du côté du <a href="https://www.doctolib.fr/dentiste/le-pre-saint-gervais">Pré-St-Gervais</a>.<br/>
# <br/>
# Doctolib vous facilite la prise de rendez-vous en ligne grâce à son moteur de recherche efficace et rapide. Vous pouvez localiser le dentiste le plus proche de votre adresse et voir ses disponibilités. Il est généralement possible de trouver une consultation dans un délai d’une semaine. Choisissez le créneau qui vous convient et confirmez votre rendez-vous.</div></p></div></div><div class="drilldown"><div class="row-center row-padding"><ol class="breadcrumb"><li>Doctolib</li><li><a href="/dentiste">Chirurgien-dentiste</a></li><li>Paris Paris 19e Arrondissement</li></ol></div></div><div class="dl-white-bg"><div class="dl-footer-content m-auto"><div class="dl-footer-container dl-footer-help-container flex dl-justify-between dl-align-items-center dl-text-center"><div class="dl-footer-help-text flex flex-wrap dl-flex-grow-shrink-auto"><div class="dl-text dl-text-title dl-text-l dl-text-bold dl-margin-r-4">Une question ? Besoin d'aide ?</div><div class="dl-text dl-text-body dl-text-s dl-text-regular">Consultez notre aide en ligne ou contactez-nous</div></div><a class="dl-button-primary dl-button dl-button-size-normal dl-flex-shrink-zero" href="https://doctolibpatient.zendesk.com/hc/fr?source=help_button" target="_blank"><span class="dl-button-label"><svg class="dl-icon dl-button-left-icon dl-icon-xsmall" fill="currentColor" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M8 14.4A6.4 6.4 0 1 0 8 1.6a6.4 6.4 0 0 0 0 12.8zm0-7.793a1.084 1.084 0 1 1 0-2.168 1.084 1.084 0 0 1 0 2.168zm1.135 4.696h-2.27a.31.31 0 0 1-.31-.31v-.619a.31.31 0 0 1 .31-.31h.31v-1.65h-.31a.31.31 0 0 1-.31-.31v-.619a.31.31 0 0 1 .31-.31h1.651a.31.31 0 0 1 .31.31v2.58h.31a.31.31 0 0 1 .31.31v.62a.31.31 0 0 1-.31.31z" fill-rule="evenodd"></path></svg>
a class="dl-text dl-text-body dl-text-s dl-text-regular dl-text-neutral-090 dl-margin-r-4" href="https://doctolib.legal/Search-transparency_DL_FR" target="_blank"> • Règles de référencement</a><a class="dl-text dl-text-body dl-text-s dl-text-regular dl-text-neutral-090 dl-margin-r-4" href="https://doctolib.legal/website-imprint" target="_blank"> • Mentions légales</a></div><div class="flex flex-wrap dl-legal-links"><span class="dl-text dl-text-body dl-text-s dl-text-regular dl-text-neutral-090 dl-margin-r-4" data-u="=Umc
# pFWdu5WYvInZu4WajVGZl1mLsFmbvlGdh5WLslWZz52bj5yd3d3LvoDc0RHa" target="_blank">Annuaire des médecins du CNOM</span><span class="dl-text dl-text-body dl-text-s dl-text-regular dl-text-neutral-090 dl-margin-r-4" data-u="=UmcpFWd
# u5WYvInZuMXZ0NXa05WZk1ycuVWanJXdylGaj1SZyRmcv5yd3d3LvoDc0RHa" target="_blank"> • Annuaire des chirurgiens-dentistes de l'ONCD</span><span class="dl-text dl-text-body dl-text-s dl-text-regular dl-text-neutral-090 dl-margin-r-4" data-u="=InZu4WajVGZl1mLsFmbvlGdh5WLslWZz52bj5yd3d3LvoDc0RHa" target="_blank"> • Ordre National des Médecins</span><span class="dl-text dl-text-body dl-text-s dl-text-regular dl-text-neutral-090 dl-margin-r-4" data-u="=InZuMXZ0NXa05WZk1ycuVWanJXdylGaj1SZyRmcv5yd3d3LvoDc0RHa" target="_blank"> • Ordre National des Chirurgiens-Dentistes</span></div></div></br></div></footer></div></div><script nonce="Dwo8vMh/G5ZqWdItRerIDg==">window.country = "fr";
# window.locale = "fr";
# window.onPartnerDomain = false;
# window.translation_keys = JSON.parse("{\"root\":{\"activerecord\":{\"models\":{\"appointment_rule_template\":\"Modèle de consigne d'information\",\"association\":\"Associations\",\"decoration\":\"Prix et distinctions\",\"establishment\":{\"one\":\"Établissement\",\"other\":\"Établissements\",\"zero\":\"Establishments\"},\"experience_period\":\"Expériences en hôpital et clinique\",\"formation\":\"Formations\",\"invoice_template\":{\"one\":\"Contrat\",\"other\":\"Contrats\",\"zero\":\"Contracts\"},\"last_update\":\"Derniers changements\",\"national_formation\":\"Diplômes de santé nationaux français\",\"office_period\":\"Expériences en cabinet\",\"other_formation\":\"Autres formations de santé\",\"publication\":\"Travaux et publications\",\"secretaryship_account\":{\"one\":\"Compte de télésecrétariat\",\"other\":\"Comptes de télésecrétariat\",\"zero\":\"Call center accounts\"},\"covid_vaccines\":{\"human_names\":{\"astrazeneca\":\"AstraZeneca\",\"janssen\":\"Janssen\",\"moderna\":\"Moderna\",\"novavax\":\"Novavax\",\"valneva\":\"Valneva\",\"pfizer\":\"BioNTech/Pfizer\",\"pfizer_children\":\"Pfizer Enfants\",\"ba1moderna\":\"Moderna BA.1\",\"ba1biontech\":\"BioNTech/Pfizer BA.1\",\"ba45biontech\":\"BioNTech/Pfizer bivalent\",\"ba45biontech_children\":\"BioNTech Ba.4-5 Enfants\",\"ba45moderna\":\"Moderna Ba.4-5\",\"pfizer_children_3mcg\":\"BioNTech/Pfizer 6 mois - 4 ans\",\"recovered_from_covid\":\"Patient ayant déjà contracté la Covid-19\"}}}},\"accounts\":{\"activity\":{\"new\":{\"reactivation_confirm_notice\":\"Votre compte a bien été réactivé ! Vous pouvez prendre rendez-vous en quelques clics chez un praticien.\",\"reactivation_failure_notice\":\"Votre compte a été supprimé après 3 ans d’inactivité. Vous pouvez recréer un compte en quelques clics pour prendre rendez-vous chez un praticien.\"}},\"age_too_young\":\"Si vous avez moins de %{min_age} ans, demandez à un parent de prendre rendez-vous pour vous depuis son compte Doctolib\",\"change_password\":{\"invalid_password\":\"Le mot de passe actuel renseigné n'est pas correct.\"},\"change_pin\":{\"invalid_password_or_pin\":\"Le mot de passe ou le code PIN renseigné n'est pas correct.\"},\"contact_infos_validation\":{\"email_label\":\"Votre adresse mail\",\"false\":\"Non, je les modifie\",\"message\":{\"without_first_name\":\"Bonjour, vos informations sont-elles à jour ?\",\"with_first_name\":\"Bonjour %{first_name}, vos informations sont-elles à jour ?\"},\"phone_label\":\"Votre numéro de téléphone\",\"title\":\"Validation de vos informations\",\"true\":\"Oui, tout est à jour\"},\"edit\":{\"account_without_phone\":\"Merci de saisir votre numéro de téléphone portable.\",\"change_password\":{\"current\":\"Mot de passe actuel\",\"new\":\"Nouveau mot de passe\",\"success\":\"Votre mot de passe a été mis à jour.\",\"title\":\"Modifier mon mot de passe\"},\"confidentiality_msg\":\"Ces données sont confidentielles et destinées au docteur.\",\"delete_account\":{\"action\":\"Supprimer mon compte\",\"confirm\":\"Cette action n'est pas réversible.\\nÊtes-vous sûr(e) de vouloir supprimer votre compte ?\",\"forbidden_msg_html\":\"Vous ne pouvez pas supprimer votre compte car vous avez des rendez-vous confirmés dans le futur. \\u003cbr/\\u003e Si vous souhaitez supprimer votre compte Doctolib, vous devez d'abord annuler ces rendez-vous.\\n\",\"msg_html\":\"Si vous ne souhaitez plus utiliser Doctolib, vous avez la possibilité de supprimer votre compte.\\u003cbr\\u003eCette action irréversible aura pour effet d'effacer vos données personnelles et de connexion de la base de données de Doctolib.\",\"title\":\"Suppression de votre compte Doctolib\"},\"email_title\":\"Votre adresse email\"},\"email_already_used\":\"Un compte Doctolib a déjà été créé avec cette adresse e-mail.\",\"email_verifications\":{\"after_booking\":{\"click_verification_link\":\"Veuillez cliquer sur le lien afin de vérifier votre adresse mail.\",\"close_button\":\"Fermer\",\"email_sent_html\":\"Pour sécuriser l'accès à vos re ...
# window.pre_authenticated_account = null;
# window.current_account = null;
# window.tanker_status = {"tanker_status":"up","poll_interval":180000,"timestamp":1672919528}
# window.flashMessages = [];</script><script nonce="Dwo8vMh/G5ZqWdItRerIDg==" src="https://assets.doctolib.fr/webpack/21104-2cd9c8a6521bd9f0e7ec.js"></script>
# <script nonce="Dwo8vMh/G5ZqWdItRerIDg==" src="https://assets.doctolib.fr/webpack/15458-5ba28c9e056c8967f59d.js"></script>
# <script nonce="Dwo8vMh/G5ZqWdItRerIDg==" src="https://assets.doctolib.fr/webpack/56782-4e660f435fef51842aa6.js"></script>
# <script nonce="Dwo8vMh/G5ZqWdItRerIDg==" src="https://assets.doctolib.fr/webpack/13993-1229a370ceb2b168eb98.js"></script>
# <script nonce="Dwo8vMh/G5ZqWdItRerIDg==" src="https://assets.doctolib.fr/webpack/69071-0b26e0eca071d60ecca2.js"></script>
# <script nonce="Dwo8vMh/G5ZqWdItRerIDg==" src="https://assets.doctolib.fr/webpack/58237-e4a79f08819068cab0aa.js"></script>
# <script nonce="Dwo8vMh/G5ZqWdItRerIDg==" src="https://assets.doctolib.fr/webpack/652-df8e9e1f24a41e7094ec.js"></script>
# <script nonce="Dwo8vMh/G5ZqWdItRerIDg==" src="https://assets.doctolib.fr/webpack/13815-717eac04d0b762078a1a.js"></script>
# <script nonce="Dwo8vMh/G5ZqWdItRerIDg==" src="https://assets.doctolib.fr/webpack/33701-45d681aa4514e14cb13c.js"></script>
# <script nonce="Dwo8vMh/G5ZqWdItRerIDg==" src="https://assets.doctolib.fr/webpack/68870-c9e70563642571287634.js"></script>
# <script nonce="Dwo8vMh/G5ZqWdItRerIDg==" src="https://assets.doctolib.fr/webpack/4287-1cb44d0794d4ed4b7119.js"></script>
# <script nonce="Dwo8vMh/G5ZqWdItRerIDg==" src="https://assets.doctolib.fr/webpack/51673-57ba75bf39b6c39b17f2.js"></script>
# <script nonce="Dwo8vMh/G5ZqWdItRerIDg==" src="https://assets.doctolib.fr/webpack/19755-7348a99c4b6d70a01e9e.js"></script>
# <script nonce="Dwo8vMh/G5ZqWdItRerIDg==" src="https://assets.doctolib.fr/webpack/19753-01bc44450b1fc93cbd9f.js"></script>
# <script nonce="Dwo8vMh/G5ZqWdItRerIDg==" src="https://assets.doctolib.fr/webpack/17244-2cf58617f9ddf0370518.js"></script>
# <script nonce="Dwo8vMh/G5ZqWdItRerIDg==" src="https://assets.doctolib.fr/webpack/43826-57452a8db0c5386c7c6d.js"></script>
# <script nonce="Dwo8vMh/G5ZqWdItRerIDg==" src="https://assets.doctolib.fr/webpack/4766-3390295dcd82adc768b0.js"></script>
# <script nonce="Dwo8vMh/G5ZqWdItRerIDg==" src="https://assets.doctolib.fr/webpack/74186-72ec8f11325c4e3e5353.js"></script>
# <script nonce="Dwo8vMh/G5ZqWdItRerIDg==" src="https://assets.doctolib.fr/webpack/13761-6d1c1976699adbf5b450.js"></script>
# <script nonce="Dwo8vMh/G5ZqWdItRerIDg==" src="https://assets.doctolib.fr/webpack/59577-8472387b6eaa42dedc79.js"></script>
# <script nonce="Dwo8vMh/G5ZqWdItRerIDg==" src="https://assets.doctolib.fr/webpack/79558-08318d59d2646913c323.js"></script>
# <script nonce="Dwo8vMh/G5ZqWdItRerIDg==" src="https://assets.doctolib.fr/webpack/2060-a15f9a782be8a6c9eccc.js"></script>
# <script nonce="Dwo8vMh/G5ZqWdItRerIDg==" src="https://assets.doctolib.fr/webpack/59882-4b182dc67a8ab4ba8551.js"></script>
# <script nonce="Dwo8vMh/G5ZqWdItRerIDg==" src="https://assets.doctolib.fr/webpack/51298-faf5eba01cd9297232f3.js"></script>
# <script nonce="Dwo8vMh/G5ZqWdItRerIDg==" src="https://assets.doctolib.fr/webpack/70596-cbbd9418fb40671133cb.js"></script>
# <script nonce="Dwo8vMh/G5ZqWdItRerIDg==" src="https://assets.doctolib.fr/webpack/patient-desktop-8664ccc65a75ff88d8fe.js"></script></body></html>

# %% [markdown]
# ### Extract the doctors
# We do some simple operations on the extracted information.

# %%
soup.title.string #Extract the web site name as a string
# Out:
# 'Chirurgien-dentiste à Paris - Paris 19e Arrondissement 75019 : Rendez-vous par Internet sous 24h - Doctolib'

# %%
soup.a.get('href') #Extract the first link of the page
# Out:
# '/dentiste/paris-75019?page=2'

# %% [markdown]
# We then find the main information. For this, we have identified the type that contains the information on the doctors.

# %%
doct = soup.findAll(type= "application/ld+json")
len(doct)
# Out:
# 3

# %% [markdown]
# The list is composed of 3 elements, but we only want the one containing the information about the doctors.

# %%
info_doc = str(doct[1])

# %% [markdown]
# A clear problem that we can underline here is the fact that this list has to be heavily processed before we can add the information to a Dataframe.
#
# ## Data Processing
# We first divide the list in different parts, each containing all the information of a single doctor.

# %%
cur_nb = info_doc.find('{') #our indice
cur_parent = 1 #nb of parenthesis to close
list_inf = []

for k in range (cur_nb+1, len(info_doc)):
    if (info_doc[k]=='{'):
        cur_parent +=1
    elif (info_doc[k] == '}'):
        cur_parent -=1 
        if (cur_parent == 0): #we found the parenthesis that closes the first parenthesis
            list_inf.append(info_doc[cur_nb+1:k])
            cur_nb = info_doc.find('{',k)
list_inf
# Out:
# ['"@context":"http://schema.org/","@type":"Physician","name":"Gabriel KOSKAS","medicalSpecialty":"Chirurgien-dentiste","legalName":"","url":"/dentiste/paris/dr-gabriel-koskas","address":{"@type":"PostalAddress","name":"","streetAddress":"41 Avenue Simon Bolivar","postalCode":"75019","addressLocality":"Paris"},"paymentAccepted":"Cash, Check, Credit card"',
#  '"@context":"http://schema.org/","@type":"Hospital","name":"Centre Dentaire Buttes Chaumont ","medicalSpecialty":"Centre dentaire","legalName":null,"url":"/centre-dentaire/paris/centre-dentaire-buttes-chaumont","address":{"@type":"PostalAddress","name":"Centre dentaire des Buttes Chaumont","streetAddress":"63 Rue Manin","postalCode":"75019","addressLocality":"Paris"},"paymentAccepted":"Cash, Check, Credit card"',
#  '"@context":"http://schema.org/","@type":"Hospital","name":"Centre médical et dentaire Stalingrad (CRAMIF)","medicalSpecialty":"Centre de santé","legalName":null,"url":"/centre-de-sante/paris/centre-medical-stalingrad","address":{"@type":"PostalAddress","name":"Centre médical Stalingrad (CRAMIF)","streetAddress":"3 Rue du Maroc","postalCode":"75019","addressLocality":"Paris"},"paymentAccepted":"Cash, Check, Credit card"',
#  '"@context":"http://schema.org/","@type":"Physician","name":"Jeanine Serouya","medicalSpecialty":"Chirurgien-dentiste","legalName":null,"url":"/dentiste/paris/jeanine-serouya","address":{"@type":"PostalAddress","name":"","streetAddress":"136 Avenue de Flandre","postalCode":"75019","addressLocality":"Paris"},"paymentAccepted":"Cash, Check"',
#  '"@context":"http://schema.org/","@type":"Physician","name":"Caroline Chenneveau","medicalSpecialty":"Chirurgien-dentiste","legalName":null,"url":"/dentiste/paris/pauline-rampin","address":{"@type":"PostalAddress","name":"Cabinet dentaire des docteurs Ventura \\u0026 Chenneveau","streetAddress":"97 Rue de Belleville","postalCode":"75019","addressLocality":"Paris"},"paymentAccepted":"Cash, Check, Credit card"',
#  '"@context":"http://schema.org/","@type":"Physician","name":"Charles CREHANGE","medicalSpecialty":"Chirurgien-dentiste","legalName":null,"url":"/dentiste/paris/charles-crehange","address":{"@type":"PostalAddress","name":"","streetAddress":"118 Avenue Jean Jaurès","postalCode":"75019","addressLocality":"Paris"},"paymentAccepted":"Cash, Check, Credit card"',
#  '"@context":"http://schema.org/","@type":"Physician","name":"Apolline TYBURCZY","medicalSpecialty":"Chirurgien-dentiste","legalName":null,"url":"/dentiste/villeneuve-le-roi/apolline-tyburczy-622c08f7-553a-495a-a156-41ae1e9559bd","address":{"@type":"PostalAddress","name":"Cabinet Laumière","streetAddress":"22 Avenue de Laumière","postalCode":"75019","addressLocality":"Paris"},"paymentAccepted":"Cash, Check, Credit card"',
#  '"@context":"http://schema.org/","@type":"Physician","name":"Mahmoud BENAZZOUK","medicalSpecialty":"Chirurgien-dentiste","legalName":"","url":"/dentiste/paris/mahmoud-benazzouk","address":{"@type":"PostalAddress","name":"","streetAddress":"145 Boulevard Sérurier","postalCode":"75019","addressLocality":"Paris"},"paymentAccepted":"Cash, Check, Credit card"',
#  '"@context":"http://schema.org/","@type":"Physician","name":"Cyrille Candet","medicalSpecialty":"Chirurgien-dentiste","legalName":null,"url":"/dentiste/paris/cyrille-candet","address":{"@type":"PostalAddress","name":"","streetAddress":"20 Rue Manin","postalCode":"75019","addressLocality":"Paris"},"paymentAccepted":"Cash, Check, Credit card"',
#  '"@context":"http://schema.org/","@type":"Physician","name":"Anne-Elisabeth PIEUS","medicalSpecialty":"Chirurgien-dentiste","legalName":null,"url":"/dentiste/paris/anne-elisabeth-pieus","address":{"@type":"PostalAddress","name":"","streetAddress":"22 Avenue de Laumière","postalCode":"75019","addressLocality":"Paris"},"paymentAccepted":"Cash, Check, Credit card"',
#  '"@context":"http://schema.org/","@type":"Physician","name":"Lamia ABDAT","medicalSpecialty":"Chirurgien-dentiste","legalName":null,"url":"/dentiste/paris/lamia-abdat","address":{"@type":"PostalAddress","name":"Cabinet Badache","streetAddress":"110 rue Petit","postalCode":"75019","addressLocality":"Paris"},"paymentAccepted":"Cash, Check, Credit card"',
#  '"@context":"http://schema.org/","@type":"Physician","name":"Kenza AYOUCHE","medicalSpecialty":"Chirurgien-dentiste","legalName":null,"url":"/dentiste/paris/kenza-ayouche","address":{"@type":"PostalAddress","name":"Centre ADDMS Crimée","streetAddress":"46 Rue de Crimée","postalCode":"75019","addressLocality":"Paris"},"paymentAccepted":""',
#  '"@context":"http://schema.org/","@type":"Physician","name":"Joelle FHIMA JOURNO","medicalSpecialty":"Chirurgien-dentiste","legalName":null,"url":"/dentiste/paris/joelle-fhima-journo","address":{"@type":"PostalAddress","name":"Cabinet dentaire Fhima Joelle","streetAddress":"5 Rue Manin","postalCode":"75019","addressLocality":"Paris"},"paymentAccepted":"Cash, Check, Credit card"',
#  '"@context":"http://schema.org/","@type":"Physician","name":"Benamar SEDDIKI","medicalSpecialty":"Chirurgien-dentiste","legalName":null,"url":"/dentiste/paris/benamar-seddiki","address":{"@type":"PostalAddress","name":"","streetAddress":"13 Rue Armand Carrel","postalCode":"75019","addressLocality":"Paris"},"paymentAccepted":"Cash, Check, Credit card"',
#  '"@context":"http://schema.org/","@type":"Physician","name":"Florent HUGUET JAIME","medicalSpecialty":"Chirurgien-dentiste","legalName":"","url":"/dentiste/paris/florent-huguet-jaime","address":{"@type":"PostalAddress","name":"Cabinet dentaire Quai de Seine","streetAddress":"49 Quai de la Seine","postalCode":"75019","addressLocality":"Paris"},"paymentAccepted":"Cash, Check, Credit card"',
#  '"@context":"http://schema.org/","@type":"Physician","name":"Jebran NAEEM RAZA","medicalSpecialty":"Chirurgien-dentiste","legalName":null,"url":"/dentiste/paris/jebran-naeem-raza","address":{"@type":"PostalAddress","name":"Centre ADDMS Crimée","streetAddress":"46 Rue de Crimée","postalCode":"75019","addressLocality":"Paris"},"paymentAccepted":""',
#  '"@context":"http://schema.org/","@type":"Physician","name":"Franck Badache","medicalSpecialty":"Chirurgien-dentiste","legalName":"FRANCK BADACHE","url":"/dentiste/paris/franck-badache","address":{"@type":"PostalAddress","name":"Cabinet Badache","streetAddress":"110 rue Petit","postalCode":"75019","addressLocality":"Paris"},"paymentAccepted":"Cash, Check, Credit card"',
#  '"@context":"http://schema.org/","@type":"Hospital","name":"Centre dentaire Archereau","medicalSpecialty":"Cabinet dentaire","legalName":null,"url":"/cabinet-dentaire/paris/centre-dentaire-archereau","address":{"@type":"PostalAddress","name":"Centre Dentaire Archereau","streetAddress":"41 Rue Archereau","postalCode":"75019","addressLocality":"Paris"},"paymentAccepted":"Cash, Check, Credit card"',
#  '"@context":"http://schema.org/","@type":"Physician","name":"Amsellem Avner","medicalSpecialty":"Chirurgien-dentiste","legalName":null,"url":"/dentiste/paris/avner-amsellem","address":{"@type":"PostalAddress","name":"Cabinet du docteur Melloul","streetAddress":"186 Rue de Crimée","postalCode":"75019","addressLocality":"Paris"},"paymentAccepted":"Cash, Check, Credit card"',
#  '"@context":"http://schema.org/","@type":"Physician","name":"Liora Barukh","medicalSpecialty":"Chirurgien-dentiste","legalName":null,"url":"/dentiste/bornel/liora-barukh","address":{"@type":"PostalAddress","name":"Cabinet dentaire du Dr AZRIA David","streetAddress":"65 Rue d\'Hautpoul","postalCode":"75019","addressLocality":"Paris"},"paymentAccepted":"Cash, Check, Credit card"']

# %%
list_inf[0]
# Out:
# '"@context":"http://schema.org/","@type":"Physician","name":"Gabriel KOSKAS","medicalSpecialty":"Chirurgien-dentiste","legalName":"","url":"/dentiste/paris/dr-gabriel-koskas","address":{"@type":"PostalAddress","name":"","streetAddress":"41 Avenue Simon Bolivar","postalCode":"75019","addressLocality":"Paris"},"paymentAccepted":"Cash, Check, Credit card"'

# %% [markdown]
# As we can observe, we now have several strings each describing a doctor.
# We are going to process each of these strings. Although the method is quite rough, it is efficient, and we obtain exactly the dataframe that we needed.

# %%
list_name, list_type, list_spe,list_adr,list_post_cod, list_cit = [],[],[],[],[],[]

for doc in list_inf: #boucle pour les noms des médecins ou des hopitals
    i=0
    cur_nb = doc.find('name')
    while (doc[cur_nb+6+i] != ','):
        i+=1
    list_name.append(doc[cur_nb+7:cur_nb+5+i])

for doc in list_inf: #boucle pour les type des médecins/hopitals
    i=0
    cur_nb = doc.find('type')
    while (doc[cur_nb+6+i] != ','):
        i+=1
    list_type.append(doc[cur_nb+7:cur_nb+5+i])

for doc in list_inf: #boucle pour les spécialités
    i=0
    cur_nb = doc.find('medicalSpecialty')
    while (doc[cur_nb+18+i] != ','):
        i+=1
    list_spe.append(doc[cur_nb+19:cur_nb+17+i])

for doc in list_inf: #boucle pour les villes
    i=0
    cur_nb = doc.find('addressLocality')
    while (doc[cur_nb+16+i] != ','):
        i+=1
    list_cit.append(doc[cur_nb+18:cur_nb+14+i])

for doc in list_inf: #boucle pour les adresses (rue et numéro)
    i=0
    cur_nb = doc.find('streetAddress')
    while (doc[cur_nb+6+i] != ','):
        i+=1
    list_adr.append(doc[cur_nb+16:cur_nb+5+i])

for doc in list_inf:#boucle pour les codes postaux
    i=0
    cur_nb = doc.find('postalCode')
    while (doc[cur_nb+11+i] != ','):
        i+=1
    list_post_cod.append(int(doc[cur_nb+13:cur_nb+10+i])) # le code postal est un entier

data = {'Name':list_name,'Type':list_type, 'Speciality':list_spe,'Address':list_adr,'City':list_cit,'Postal_Code':list_post_cod}
df = pd.DataFrame(data)
display(df)
# Out:
#                                               Name       Type  \
# 0                                   Gabriel KOSKAS  Physician
# 1                 Centre Dentaire Buttes Chaumont    Hospital
# 2   Centre médical et dentaire Stalingrad (CRAMIF)   Hospital
# 3                                  Jeanine Serouya  Physician
# 4                              Caroline Chenneveau  Physician
# 5                                 Charles CREHANGE  Physician
# 6                                Apolline TYBURCZY  Physician
# 7                                Mahmoud BENAZZOUK  Physician
# 8                                   Cyrille Candet  Physician
# 9                             Anne-Elisabeth PIEUS  Physician
# 10                                     Lamia ABDAT  Physician
# 11                                   Kenza AYOUCHE  Physician
# 12                             Joelle FHIMA JOURNO  Physician
# 13                                 Benamar SEDDIKI  Physician
# 14                            Florent HUGUET JAIME  Physician
# 15                               Jebran NAEEM RAZA  Physician
# 16                                  Franck Badache  Physician
# 17                       Centre dentaire Archereau   Hospital
# 18                                  Amsellem Avner  Physician
# 19                                    Liora Barukh  Physician
#
#              Speciality                  Address   City  Postal_Code
# 0   Chirurgien-dentiste  41 Avenue Simon Bolivar  Paris        75019
# 1       Centre dentaire             63 Rue Manin  Paris        75019
# 2       Centre de santé           3 Rue du Maroc  Paris        75019
# 3   Chirurgien-dentiste    136 Avenue de Flandre  Paris        75019
# 4   Chirurgien-dentiste     97 Rue de Belleville  Paris        75019
# 5   Chirurgien-dentiste   118 Avenue Jean Jaurès  Paris        75019
# 6   Chirurgien-dentiste    22 Avenue de Laumière  Paris        75019
# 7   Chirurgien-dentiste   145 Boulevard Sérurier  Paris        75019
# 8   Chirurgien-dentiste             20 Rue Manin  Paris        75019
# 9   Chirurgien-dentiste    22 Avenue de Laumière  Paris        75019
# 10  Chirurgien-dentiste            110 rue Petit  Paris        75019
# 11  Chirurgien-dentiste         46 Rue de Crimée  Paris        75019
# 12  Chirurgien-dentiste              5 Rue Manin  Paris        75019
# 13  Chirurgien-dentiste     13 Rue Armand Carrel  Paris        75019
# 14  Chirurgien-dentiste      49 Quai de la Seine  Paris        75019
# 15  Chirurgien-dentiste         46 Rue de Crimée  Paris        75019
# 16  Chirurgien-dentiste            110 rue Petit  Paris        75019
# 17     Cabinet dentaire         41 Rue Archereau  Paris        75019
# 18  Chirurgien-dentiste        186 Rue de Crimée  Paris        75019
# 19  Chirurgien-dentiste        65 Rue d'Hautpoul  Paris        75019
