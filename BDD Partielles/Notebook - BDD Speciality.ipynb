# %% [markdown]
# # MODS203 Project
# ## Ryan Borhani, Mathilde Froger, Apolline Isaia, Solal Urien
# ### Load libraries

# %%
import pandas as pd
import urllib.request
import re
import requests
import random
import unidecode
import time

from urllib.error import HTTPError
from bs4 import BeautifulSoup as bs
from urllib.request import Request, urlopen

# %% [markdown]
# ### List of towns

# %%
my_file = open("Communes.txt", "r")
data = my_file.read()
town_list = data.split("\n")
my_file.close()

# %% [markdown]
# ### Normalizing the names

# %%
for k in range(len(town_list)) :
    town_list[k] = unidecode.unidecode(town_list[k].lower())
    town_list[k] = town_list[k].replace('\'','-')
    town_list[k] = town_list[k].replace(' ','-')
    town_list[k] = town_list[k].replace('ç','c')
len(town_list)
# Out:
# 190

# %% [markdown]
# ### Adding the *arrondissements* of Paris, Marseille and Lyon

# %%
for k in range (1,21): #Paris has 20 arrondissements
    town_list.insert(1,'paris-'+str(75000+k))
    if k<17: #Marseille has 16 arrondissements
        town_list.insert(2+k,'marseille-'+str(13000+k))
    if k<10: #Lyon has 9 arrondissements
        town_list.insert(3+2*k,'lyon-'+str(69000+k))

# %%
len(town_list)
# Out:
# 235

# %% [markdown]
# ### List of speciality

# %%
my_file2 = open("Speciality.txt", "r")
data2 = my_file2.read()
spe_list = data2.split("\n")
my_file2.close()
spe_list
# Out:
# ['addictologue',
#  'cancerologue',
#  'chirurgien',
#  'dermatologue',
#  'dieteticien',
#  'gynecologue',
#  'infectiologue',
#  'neurologue',
#  'ophtalmologue',
#  'pediatre',
#  'pneumologue',
#  'psychiatre',
#  'radiologue',
#  'rhumatologue']

# %%
spe_list = spe_list[0:2]+[spe_list[4]]+[spe_list[8]]

# %% [markdown]
# Du fait des impératifs de temps et des contraintes de scrapping (notamment l'utilisation d'un VPN ainsi que le peu de données récoltés pour une requête), nous sélectionnons quatre spécialités sur lesquelles nous allons scrapper.
# Nous aurons tout de même certaines des spécialités de la liste ci-dessus car les retours de doctolib pour un médecins spécialiste sont imprécis.

# %%
spe_list
# Out:
# ['addictologue', 'cancerologue', 'dieteticien', 'ophtalmologue']

# %% [markdown]
# The speciality strings are already normalized.
# ### Make the request and extract the HTML code
# For all departments, we request the HTML code. For this doing, we use the previous list and convert the strings into the model that is used for the *Doctolib* URL adress.
# The collection of the data was particularly complex given the reaction of the *Doctolib* website.
#
# **Warning 1: the repeated requests provoke a 403 or 429 HTTP error, therefore, you have to change the VPN address or proxy each time you get such error**
#
# **Warning 2: The code might be particularly long to compute, especially with a VPN**

# %%
hdr = {'User-Agent': 'Mozilla/6.0'}
list_HTML = []
curr_spe = 0
spe = spe_list[curr_spe]

for town in town_list:
    try :
        url = 'https://www.doctolib.fr/'+spe+'/'+town
        req = Request(url,headers=hdr)
        page = urlopen(req)
        soup = bs(page,'html.parser')
        list_HTML.append(soup)
    except HTTPError as err:
        if err.code == 404: ## we only except 404 HTTP errors: this are the cities that do not have doctors
            print(town)
        else:
            raise

# %%
len(list_HTML)
# Out:
# 3

# %% [markdown]
# This list has to be heavily processed before we can add the information to a Dataframe.
#
# ## Data Processing
# We previously learned (1st part of the project) how the HTML code was structured.
# We therefore divide the list in different parts, each containing the information of all the doctors in a given department.

# %%
all_doc = []

for dep_doc in list_HTML:
    all_doc = all_doc + [str(dep_doc.findAll(type= "application/ld+json")[1])]
len(all_doc)
# Out:
# 3

# %% [markdown]
# We subsequently divide the list, each part containing all the information of a single doctor.

# %%
list_inf = []

for depart_doc in all_doc:
    cur_nb = depart_doc.find('{') #our indice
    cur_parent = 1 #nb of parenthesis to close

    for k in range (cur_nb+1, len(depart_doc)):
        if (depart_doc[k]=='{'):
            cur_parent +=1
        elif (depart_doc[k] == '}'):
            cur_parent -=1 
            if (cur_parent == 0): #we found the parenthesis that closes the first parenthesis
                list_inf.append(depart_doc[cur_nb+1:k])
                cur_nb = depart_doc.find('{',k)
len(list_inf)
# Out:
# 60

# %% [markdown]
# We now have numerous strings, each describing a doctor.
# We are going to process these strings one by one to obtain exactly the dataframe we want. We also add more information to the DataFrame with the *Payment_accepted* column.

# %%
list_name, list_type, list_spe,list_adr,list_post_cod, list_cit, list_pay = [],[],[],[],[],[],[]

for doc in list_inf: #boucle pour les noms des médecins ou des hopitals
    i=0
    cur_nb = doc.find('name')
    while (doc[cur_nb+6+i] != ','):
        i+=1
    list_name.append(doc[cur_nb+7:cur_nb+5+i])

for doc in list_inf: #boucle pour les type des médecins/hopitals
    i=0
    cur_nb = doc.find('type')
    while (doc[cur_nb+6+i] != ','):
        i+=1
    list_type.append(doc[cur_nb+7:cur_nb+5+i])

for doc in list_inf: #boucle pour les spécialités
    i=0
    cur_nb = doc.find('medicalSpecialty')
    while (doc[cur_nb+18+i] != ','):
        i+=1
    list_spe.append(doc[cur_nb+19:cur_nb+17+i])

for doc in list_inf: #boucle pour les villes
    i=0
    cur_nb = doc.find('addressLocality')
    while (doc[cur_nb+16+i] != ','):
        i+=1
    list_cit.append(doc[cur_nb+18:cur_nb+14+i])

for doc in list_inf: #boucle pour les adresses (rue et numéro)
    i=0
    cur_nb = doc.find('streetAddress')
    while (doc[cur_nb+6+i] != ','):
        i+=1
    list_adr.append(doc[cur_nb+16:cur_nb+5+i])

for doc in list_inf:#boucle pour les codes postaux
    i=0
    cur_nb = doc.find('postalCode')
    while (doc[cur_nb+11+i] != ','):
        i+=1
    try:
        list_post_cod.append(int(doc[cur_nb+13:cur_nb+10+i].replace(' ',''))) # le code postal est un entier, on applique donc un rapide formatage avant de transformer le string en int
    except:
        list_post_cod.append(doc[cur_nb+13:cur_nb+10+i]) #Si la transformation en integer n'est pas possible, on laisse le format string

for doc in list_inf: #boucle pour les moyens de paiement
    i=0
    cur_nb = doc.find('paymentAccepted')
    while (cur_nb+i != len(doc)):
        i+=1
    list_pay.append(doc[cur_nb+18:len(doc)-1])

data = {'Name':list_name,'Type':list_type, 'Speciality':list_spe,'Address':list_adr,'City':list_cit,'Postal_Code':list_post_cod, 'Payment_accepted':list_pay}
df = pd.DataFrame(data)
display(df)
# Out:
#                                                  Name       Type  \
# 0                                Noemie HENNEQUIN-BOI  Physician
# 1                                Laurane Aboualchamat  Physician
# 2                                      Camille Chiaro  Physician
# 3                                      Adrien Pecourt  Physician
# 4                              Pharmacie Cleyet Merle   Hospital
# 5                                         Selin ZORLU  Physician
# 6                                      Claire Boulard  Physician
# 7                                  Laetitia Dupoirier  Physician
# 8                                        Valérie Sion  Physician
# 9                                         Méryl Audia  Physician
# 10                                    Justine GENTNER  Physician
# 11                                 Christine Scheibel  Physician
# 12                                    Léa PAGNONCELLI  Physician
# 13                                    Nadjim Kherroub  Physician
# 14                                    François DEBRAS  Physician
# 15                                   Virginie Di Tore  Physician
# 16                                           Lea LANG  Physician
# 17                                     Laura AGUILERA  Physician
# 18                               Véronique FAUCONNIER  Physician
# 19                                        Méryl Audia  Physician
# 20                           Virginie CLAVEAU GALLARD  Physician
# 21                                      Emmanuel Huet  Physician
# 22                                   Jennifer BLATRIX  Physician
# 23                                  Catherine GAZEVIC  Physician
# 24                                   Jennifer BLATRIX  Physician
# 25                                    Héléna Mitouard  Physician
# 26                                        Leila ABOUN  Physician
# 27                           Virginie CLAVEAU GALLARD  Physician
# 28                                      Maud VIDALENC  Physician
# 29                                     Maud GIORSETTI  Physician
# 30                                     Maxime REGNIER  Physician
# 31                                    Suhela OUANGOLO  Physician
# 32                                   Magali MAZMANIAN  Physician
# 33                                     Justine ZAOUCH  Physician
# 34                                  Jonathan LUTTMANN  Physician
# 35                                       Stélina Chal  Physician
# 36                                  Chaimae Benmoussa  Physician
# 37  Centre Municipal du Gâtinais (Saint-Fargeau-Po...   Hospital
# 38                                       Marie  STEVA  Physician
# 39                                        Chloé Rocco  Physician
# 40                                     Léa Napolitano  Physician
# 41                               Véronique BROS-FABRE  Physician
# 42                                    Nathalie JOYARD  Physician
# 43                                   Alessandra VACCA  Physician
# 44                                     Bettie Testier  Physician
# 45                                        Anaïs Couve  Physician
# 46                            Valérie MERY MANDEVILLE  Physician
# 47            Centre diététique Naturhouse - Caveirac   Hospital
# 48                                       Monika Dazin  Physician
# 49                           Pharmacie de Courbessac    Hospital
# 50                                     Manon Serville  Physician
# 51                                     Sophie Davoine  Physician
# 52                                    Cécile Bertrand  Physician
# 53                               Amandine Ribes-Ricou  Physician
# 54                                      Tiffany LEBRE  Physician
# 55                                    Perrine Sanchez  Physician
# 56                                   Victoria Arthaud  Physician
# 57                                   Florence DELENNE  Physician
# 58                                   Emilie CHERTEMPS  Physician
# 59                                        Célia LE DU  Physician
#
#              Speciality                          Address  \
# 0         Diététicienne       2 Rue Général de Castelnau
# 1         Diététicienne                 5 Rue des Landes
# 2         Diététicienne               1a Rue des Romains
# 3           Diététicien         Rue Jean-Pierre BELTOISE
# 4             Pharmacie              61 Route de Kuntzig
# 5         Diététicienne            1 Rue des Hirondelles
# 6         Diététicienne            11 Place Saint-Benoît
# 7         Diététicienne                1 Rue de l'Église
# 8         Diététicienne                2a Route d'Evange
# 9         Diététicienne                  46 Rue de Nancy
# 10        Diététicienne           95 Rue Fridtjof Nansen
# 11        Diététicienne      2a Rue du chateau de Merten
# 12        Diététicienne             30 Rue du Presbytère
# 13          Diététicien               47 Rue de l'Europe
# 14          Diététicien            3c Rue Jules Massenet
# 15        Diététicienne              3 Rue Pablo Picasso
# 16        Diététicienne                     28 Grand Rue
# 17          Diététicien         1 Rue du Maréchal Joffre
# 18        Diététicienne                   17 Rue de Metz
# 19        Diététicienne                   17 Rue de Metz
# 20        Diététicienne           274 Avenue Marc Jaquet
# 21          Diététicien                    5 Rue Poileux
# 22        Diététicienne           272 Avenue Marc Jaquet
# 23        Diététicienne          272 Avenue Marc Jacquet
# 24        Diététicienne         56 Boulevard de l'Almont
# 25          Diététicien            11bis Rue Félix Poyez
# 26        Diététicienne     50 Boulevard Aristide Briand
# 27        Diététicienne         56 Boulevard de l'Almont
# 28        Diététicienne              2 Rue Saint-Nicolas
# 29        Diététicienne            15 Rue du Clos Fleuri
# 30          Diététicien           199 Rue Nelson Mandela
# 31        Diététicienne            8b Route de Saint-Leu
# 32        Diététicienne             20 Avenue du 23 Août
# 33        Diététicienne        116 Chemin des Tournesols
# 34          Diététicien  2 Impasse du Moulin de la Seine
# 35        Diététicienne  2 Impasse du Moulin de la Seine
# 36        Diététicienne           101 Allée des Oeillets
# 37      Centre de santé       98 Avenue de Fontainebleau
# 38        Diététicienne              Avenue des Regalles
# 39        Diététicienne      37 Allée des Pignons Blancs
# 40        Diététicienne             20 Rue Jean Castagno
# 41        Diététicienne            621 Chemin des Sports
# 42        Diététicienne                70 Route d'Anduze
# 43        Diététicienne              77 Rue Jean Bernard
# 44        Diététicienne              48 Place des Arènes
# 45        Diététicienne        2 Rue du 11 Novembre 1918
# 46        Diététicienne                2008 Route d'Alès
# 47  Cabinet paramédical                 6 Route de Nîmes
# 48        Diététicienne                  63 Rue de Sauve
# 49            Pharmacie           2872 Rte de Courbessac
# 50          Diététicien                     6 Rue Régale
# 51        Diététicienne          15 Rue de la Casernette
# 52          Diététicien                    Rue du Levant
# 53        Diététicienne                    38 Rue Roussy
# 54        Diététicienne            59 Avenue Jean Jaurès
# 55        Diététicienne        1851 Avenue Marechal Juin
# 56        Diététicienne        112 Allée du Mas de ville
# 57        Diététicienne              3 Rue de la Bandido
# 58        Diététicienne             94 Rue de Garrigotte
# 59        Diététicienne             1 Impasse du Mistral
#
#                          City  Postal_Code          Payment_accepted
# 0                  Thionville        57100         Cash, Credit card
# 1                  Thionville        57100  Cash, Check, Credit card
# 2                        Yutz        57970               Cash, Check
# 3                    Terville        57180  Cash, Check, Credit card
# 4                        Yutz        57970
# 5                   Basse-Ham        57970               Cash, Check
# 6                    Guénange        57310               Cash, Check
# 7                 Metzervisse        57940               Cash, Check
# 8        Breistroff-la-Grande        57570  Cash, Check, Credit card
# 9                   Amnéville        57360               Cash, Check
# 10                  Amnéville        57360  Cash, Check, Credit card
# 11                  Amnéville        57360  Cash, Check, Credit card
# 12                 Hagondange        57300                      Cash
# 13                  Amnéville        57360  Cash, Check, Credit card
# 14                     Rombas        57120  Cash, Check, Credit card
# 15                     Ennery        57365  Cash, Check, Credit card
# 16         Maizières-lès-Metz        57280               Cash, Check
# 17             Audun-le-Tiche        57390  Cash, Check, Credit card
# 18               Val de Briey        54150               Cash, Check
# 19               Val de Briey        54150               Cash, Check
# 20                      Melun        77000  Cash, Check, Credit card
# 21                      Melun        77000               Cash, Check
# 22                      Melun        77000  Cash, Check, Credit card
# 23                      Melun        77000               Cash, Check
# 24                      Melun        77000  Cash, Check, Credit card
# 25                      Melun        77000  Cash, Check, Credit card
# 26                      Melun        77000               Cash, Check
# 27                      Melun        77000  Cash, Check, Credit card
# 28                   Rubelles        77950               Cash, Check
# 29              Vaux-le-Pénil        77000  Cash, Check, Credit card
# 30           Le Mée-sur-Seine        77350               Cash, Check
# 31                     Cesson        77240  Cash, Check, Credit card
# 32                Bois-le-Roi        77590  Cash, Check, Credit card
# 33                      Nandy        77176  Cash, Check, Credit card
# 34   Saint-Fargeau-Ponthierry        77310         Cash, Credit card
# 35   Saint-Fargeau-Ponthierry        77310               Cash, Check
# 36                      Nandy        77176        Check, Credit card
# 37   Saint-Fargeau-Ponthierry        77310        Check, Credit card
# 38          Savigny-le-Temple        77176         Cash, Credit card
# 39        Le Châtelet-en-Brie        77820               Cash, Check
# 40                       Alès        30100  Cash, Check, Credit card
# 41                       Alès        30100               Cash, Check
# 42          Boisset-et-Gaujac        30140  Cash, Check, Credit card
# 43                    Foissac        30700               Cash, Check
# 44                    Quissac        30260
# 45                La Calmette        30190  Cash, Check, Credit card
# 46               Villevieille        30250  Cash, Check, Credit card
# 47                   Caveirac        30820
# 48                      Nîmes        30900               Cash, Check
# 49                      Nîmes        30000
# 50                      Nîmes        30000               Cash, Check
# 51                      Nîmes        30900               Cash, Check
# 52                  Calvisson        30420               Cash, Check
# 53                      Nîmes        30000               Cash, Check
# 54                      Nîmes        30900  Cash, Check, Credit card
# 55                      Nîmes        30000  Cash, Check, Credit card
# 56                      Nîmes        30000
# 57                      Nîmes        30000  Cash, Check, Credit card
# 58               Marguerittes        30320               Cash, Check
# 59  Saint-Bauzille-de-Montmel        34160               Cash, Check

# %% [markdown]
# ### Export the Data

# %%
df.to_csv("Dataset-Speciality.csv", mode='a', index = False, header=False)
