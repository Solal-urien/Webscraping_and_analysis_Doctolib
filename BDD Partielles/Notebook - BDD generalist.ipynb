# %% [markdown]
# # MODS203 Project
# ## Ryan Borhani, Mathilde Froger, Apolline Isaia, Solal Urien
# ### Load libraries

# %%
import pandas as pd
import urllib.request
import re
import requests
import random
import unidecode

from bs4 import BeautifulSoup as bs
from urllib.request import Request, urlopen

# %% [markdown]
# ### List of towns

# %%
my_file = open("Communes.txt", "r")
data = my_file.read()
town_list = data.split("\n")
my_file.close()

# %% [markdown]
# ### Normalizing the names

# %%
for k in range(len(town_list)) :
    town_list[k] = unidecode.unidecode(town_list[k].lower())
    town_list[k] = town_list[k].replace('\'','-')
    town_list[k] = town_list[k].replace(' ','-')
    town_list[k] = town_list[k].replace('ç','c')
len(town_list)
# Out:
# 190

# %% [markdown]
# ### Adding the *arrondissements* of Paris, Marseille and Lyon

# %%
for k in range (1,21): #Paris has 20 arrondissements
    town_list.insert(1,'paris-'+str(75000+k))
    if k<17: #Marseille has 16 arrondissements
        town_list.insert(2+k,'marseille-'+str(13000+k))
    if k<10: #Lyon has 9 arrondissements
        town_list.insert(3+2*k,'lyon-'+str(69000+k))

# %%
town_list
# Out:
# ['paris',
#  'paris-75020',
#  'paris-75019',
#  'paris-75018',
#  'paris-75017',
#  'paris-75016',
#  'paris-75015',
#  'paris-75014',
#  'paris-75013',
#  'paris-75012',
#  'paris-75011',
#  'paris-75010',
#  'paris-75009',
#  'paris-75008',
#  'paris-75007',
#  'paris-75006',
#  'paris-75005',
#  'paris-75004',
#  'paris-75003',
#  'paris-75002',
#  'paris-75001',
#  'marseille',
#  'marseille-13016',
#  'marseille-13015',
#  'marseille-13014',
#  'marseille-13013',
#  'marseille-13012',
#  'marseille-13011',
#  'marseille-13010',
#  'marseille-13009',
#  'marseille-13008',
#  'marseille-13007',
#  'marseille-13006',
#  'marseille-13005',
#  'marseille-13004',
#  'marseille-13003',
#  'marseille-13002',
#  'marseille-13001',
#  'lyon',
#  'lyon-69009',
#  'lyon-69008',
#  'lyon-69007',
#  'lyon-69006',
#  'lyon-69005',
#  'lyon-69004',
#  'lyon-69003',
#  'lyon-69002',
#  'lyon-69001',
#  'toulouse',
#  'nice',
#  'nantes',
#  'montpellier',
#  'strasbourg',
#  'bordeaux',
#  'lille',
#  'rennes',
#  'reims',
#  'saint-etienne',
#  'le-havre',
#  'toulon',
#  'grenoble',
#  'dijon',
#  'angers',
#  'nimes',
#  'villeurbanne',
#  'saint-denis',
#  'le-mans',
#  'aix-en-provence',
#  'clermont-ferrand',
#  'brest',
#  'tours',
#  'amiens',
#  'limoges',
#  'annecy',
#  'perpignan',
#  'boulogne-billancourt',
#  'besancon',
#  'metz',
#  'orleans',
#  'rouen',
#  'saint-denis',
#  'argenteuil',
#  'mulhouse',
#  'montreuil',
#  'caen',
#  'nancy',
#  'saint-paul',
#  'tourcoing',
#  'roubaix',
#  'nanterre',
#  'avignon',
#  'vitry-sur-seine',
#  'poitiers',
#  'creteil',
#  'dunkerque',
#  'versailles',
#  'asnieres-sur-seine',
#  'aubervilliers',
#  'colombes',
#  'aulnay-sous-bois',
#  'saint-pierre',
#  'cherbourg-en-cotentin',
#  'courbevoie',
#  'fort-de-france',
#  'rueil-malmaison',
#  'pau',
#  'la-rochelle',
#  'le-tampon',
#  'beziers',
#  'champigny-sur-marne',
#  'saint-maur-des-fosses',
#  'calais',
#  'cannes',
#  'antibes',
#  'saint-nazaire',
#  'colmar',
#  'merignac',
#  'drancy',
#  'ajaccio',
#  'issy-les-moulineaux',
#  'bourges',
#  'noisy-le-grand',
#  'quimper',
#  'venissieux',
#  'la-seyne-sur-mer',
#  'cergy',
#  'valence',
#  'levallois-perret',
#  'villeneuve-d-ascq',
#  'antony',
#  'pessac',
#  'troyes',
#  'montauban',
#  'neuilly-sur-seine',
#  'ivry-sur-seine',
#  'niort',
#  'cayenne',
#  'chambery',
#  'clichy',
#  'lorient',
#  'sarcelles',
#  'beauvais',
#  'la-roche-sur-yon',
#  'hyeres',
#  'le-blanc-mesnil',
#  'meaux',
#  'saint-andre',
#  'saint-quentin',
#  'maisons-alfort',
#  'villejuif',
#  'cholet',
#  'epinay-sur-seine',
#  'pantin',
#  'vannes',
#  'evry',
#  'narbonne',
#  'les-abymes',
#  'chelles',
#  'frejus',
#  'fontenay-sous-bois',
#  'saint-louis',
#  'arles',
#  'bondy',
#  'sartrouville',
#  'clamart',
#  'bobigny',
#  'laval',
#  'bayonne',
#  'grasse',
#  'corbeil-essonnes',
#  'evreux',
#  'albi',
#  'sevran',
#  'massy',
#  'cagnes-sur-mer',
#  'vincennes',
#  'saint-ouen',
#  'belfort',
#  'montrouge',
#  'martigues',
#  'suresnes',
#  'vaulx-en-velin',
#  'charleville-mezieres',
#  'brive-la-gaillarde',
#  'saint-malo',
#  'blois',
#  'saint-herblain',
#  'carcassonne',
#  'chalon-sur-saone',
#  'saint-brieuc',
#  'gennevilliers',
#  'chalons-en-champagne',
#  'salon-de-provence',
#  'saint-priest',
#  'meudon',
#  'chateauroux',
#  'aubagne',
#  'rosny-sous-bois',
#  'bastia',
#  'puteaux',
#  'choisy-le-roi',
#  'livry-gargan',
#  'angouleme',
#  'valenciennes',
#  'sete',
#  'istres',
#  'mantes-la-jolie',
#  'alfortville',
#  'saint-laurent-du-maroni',
#  'talence',
#  'noisy-le-sec',
#  'caluire-et-cuire',
#  'bourg-en-bresse',
#  'castres',
#  'garges-les-gonesse',
#  'la-courneuve',
#  'gap',
#  'boulogne-sur-mer',
#  'le-cannet',
#  'arras',
#  'tarbes',
#  'reze',
#  'saint-germain-en-laye',
#  'compiegne',
#  'bron',
#  'wattrelos',
#  'thionville',
#  'melun',
#  'ales',
#  'draguignan',
#  'le-lamentin',
#  'douai',
#  'chartres',
#  'anglet',
#  'bagneux']

# %% [markdown]
# ### Make the request and extract the HTML code
# For all departments, we request the HTML code. For this doing, we use the previous list and convert the strings into the model that is used for the *Doctolib* URL adress.
# The collection of the data was particularly complex given the reaction of the *Doctolib* website.
#
# **Warning 1: the repeated requests might provoke a 403 HTTP error, using a VPN might therefore be useful**
#
# **Warning 2: The code might be particularly long to compute**

# %%
hdr = {'User-Agent': 'Mozilla/6.0'}
list_HTML = []

for town in town_list:
    url = 'https://www.doctolib.fr/medecin-generaliste/'+town
    req = Request(url,headers=hdr)
    page = urlopen(req)
    soup = bs(page,'html.parser')
    list_HTML.append(soup)

# %%
len(list_HTML)
# Out:
# 235

# %% [markdown]
# This list has to be heavily processed before we can add the information to a Dataframe.
#
# ## Data Processing
# We previously learned (1st part of the project) how the HTML code was structured.
# We therefore divide the list in different parts, each containing the information of all the doctors in a given department.

# %%
all_doc = []
for dep_doc in list_HTML:
    all_doc = all_doc + [str(dep_doc.findAll(type= "application/ld+json")[1])]
len(all_doc)
# Out:
# 235

# %%
all_doc[0]
# Out:
# '<script type="application/ld+json">[{"@context":"http://schema.org/","@type":"Physician","name":"Katia SEBBAN","medicalSpecialty":"Médecin généraliste","legalName":"","url":"/medecin-generaliste/paris/katia-sebban","address":{"@type":"PostalAddress","name":"","streetAddress":"178 Bis, Rue Pelleport","postalCode":"75020","addressLocality":"Paris"},"paymentAccepted":"Cash, Check, Credit card"},{"@context":"http://schema.org/","@type":"Hospital","name":"Centre médical Réaumur - CPAM Paris","medicalSpecialty":"Centre médical et dentaire","legalName":null,"url":"/centre-medical-et-dentaire/paris/centre-medical-reaumur-cpam-paris","address":{"@type":"PostalAddress","name":"Centre médical Réaumur - CPAM Paris","streetAddress":"106 Rue Réaumur","postalCode":"75002","addressLocality":"Paris"},"paymentAccepted":"Cash, Check, Credit card"},{"@context":"http://schema.org/","@type":"Physician","name":"Sven THILL","medicalSpecialty":"Médecin généraliste","legalName":null,"url":"/medecin-generaliste/paris/sven-thill","address":{"@type":"PostalAddress","name":"Maison de Santé Pluridisciplinaire Pelleport","streetAddress":"77 Rue Pelleport","postalCode":"75020","addressLocality":"Paris"},"paymentAccepted":"Cash, Check, Credit card"},{"@context":"http://schema.org/","@type":"Physician","name":"Simon OHAYON","medicalSpecialty":"Médecin généraliste","legalName":null,"url":"/medecin-generaliste/paris/simon-ohayon","address":{"@type":"PostalAddress","name":"","streetAddress":"33 Rue du Ranelagh","postalCode":"75016","addressLocality":"Paris"},"paymentAccepted":"Cash, Check, Credit card"},{"@context":"http://schema.org/","@type":"Physician","name":"Amélie Aïm-Eusébi","medicalSpecialty":"Médecin généraliste","legalName":null,"url":"/medecin-generaliste/paris/amelie-aim-eusebi-paris","address":{"@type":"PostalAddress","name":"Maison de santé pluriprofessionnelle Épinettes Grandes Carrières","streetAddress":"186 Boulevard Ney","postalCode":"75018","addressLocality":"Paris"},"paymentAccepted":"Cash, Check, Credit card"},{"@context":"http://schema.org/","@type":"Physician","name":"Benedikta Reiss","medicalSpecialty":"Spécialiste en médecine interne","legalName":null,"url":"/medecine-interne/paris/benedikta-reiss","address":{"@type":"PostalAddress","name":"Cabinet médical ","streetAddress":"4 bis Avenue Saint-Honoré d\'Eylau","postalCode":"75016","addressLocality":"Paris"},"paymentAccepted":"Cash, Credit card"},{"@context":"http://schema.org/","@type":"Physician","name":"Khoa Luat NGUYEN","medicalSpecialty":"Médecin généraliste","legalName":null,"url":"/medecin-generaliste/paris/khoa-luat-nguyen-paris","address":{"@type":"PostalAddress","name":"Cabinet médical de l’ouest","streetAddress":"121 Rue de l\'Ouest","postalCode":"75014","addressLocality":"Paris"},"paymentAccepted":"Cash, Check, Credit card"},{"@context":"http://schema.org/","@type":"Physician","name":"Firas Al Kaied","medicalSpecialty":"Médecin généraliste","legalName":null,"url":"/medecin-generaliste/paris/firas-al-kaied","address":{"@type":"PostalAddress","name":"Cabinet du docteur Firas Al Kaied","streetAddress":"258 Rue Marcadet","postalCode":"75018","addressLocality":"Paris"},"paymentAccepted":"Cash, Check, Credit card"},{"@context":"http://schema.org/","@type":"Physician","name":"Anaëlle LINDIVAT","medicalSpecialty":"Médecin généraliste","legalName":null,"url":"/medecin-generaliste/paris/anaelle-lindivat","address":{"@type":"PostalAddress","name":"Cabinet médical Santé Amelot","streetAddress":"62 Rue Amelot","postalCode":"75011","addressLocality":"Paris"},"paymentAccepted":"Cash, Check, Credit card"},{"@context":"http://schema.org/","@type":"Physician","name":"Jean-Francois Pagenel","medicalSpecialty":"Médecin généraliste","legalName":null,"url":"/medecin-generaliste/paris/jean-francois-pagenel","address":{"@type":"PostalAddress","name":"","streetAddress":"88 Bd Saint-Germain","postalCode":"75005","addressLocality":"Paris"},"paymentAccepted":"Cash, Check"},{"@context":"http://schema.org/" ...

# %% [markdown]
# We subsequently divide the list, each part containing all the information of a single doctor.

# %%
list_inf = []

for depart_doc in all_doc:
    cur_nb = depart_doc.find('{') #our indice
    cur_parent = 1 #nb of parenthesis to close

    for k in range (cur_nb+1, len(depart_doc)):
        if (depart_doc[k]=='{'):
            cur_parent +=1
        elif (depart_doc[k] == '}'):
            cur_parent -=1 
            if (cur_parent == 0): #we found the parenthesis that closes the first parenthesis
                list_inf.append(depart_doc[cur_nb+1:k])
                cur_nb = depart_doc.find('{',k)
len(list_inf)
# Out:
# 4751

# %% [markdown]
# We now have numerous strings, each describing a doctor.
# We are going to process these strings one by one to obtain exactly the dataframe we want. We also add more information to the DataFrame with the *Payment_accepted* column.

# %%
list_name, list_type, list_spe,list_adr,list_post_cod, list_cit, list_pay = [],[],[],[],[],[],[]

for doc in list_inf: #boucle pour les noms des médecins ou des hopitals
    i=0
    cur_nb = doc.find('name')
    while (doc[cur_nb+6+i] != ','):
        i+=1
    list_name.append(doc[cur_nb+7:cur_nb+5+i])

for doc in list_inf: #boucle pour les type des médecins/hopitals
    i=0
    cur_nb = doc.find('type')
    while (doc[cur_nb+6+i] != ','):
        i+=1
    list_type.append(doc[cur_nb+7:cur_nb+5+i])

for doc in list_inf: #boucle pour les spécialités
    i=0
    cur_nb = doc.find('medicalSpecialty')
    while (doc[cur_nb+18+i] != ','):
        i+=1
    list_spe.append(doc[cur_nb+19:cur_nb+17+i])

for doc in list_inf: #boucle pour les villes
    i=0
    cur_nb = doc.find('addressLocality')
    while (doc[cur_nb+16+i] != ','):
        i+=1
    list_cit.append(doc[cur_nb+18:cur_nb+14+i])

for doc in list_inf: #boucle pour les adresses (rue et numéro)
    i=0
    cur_nb = doc.find('streetAddress')
    while (doc[cur_nb+6+i] != ','):
        i+=1
    list_adr.append(doc[cur_nb+16:cur_nb+5+i])

for doc in list_inf:#boucle pour les codes postaux
    i=0
    cur_nb = doc.find('postalCode')
    while (doc[cur_nb+11+i] != ','):
        i+=1
    try:
        list_post_cod.append(int(doc[cur_nb+13:cur_nb+10+i].replace(' ',''))) # le code postal est un entier, on applique donc un rapide formatage avant de transformer le string en int
    except:
        list_post_cod.append(doc[cur_nb+13:cur_nb+10+i]) #Si la transformation en integer n'est pas possible, on laisse le format string

for doc in list_inf: #boucle pour les moyens de paiement
    i=0
    cur_nb = doc.find('paymentAccepted')
    while (cur_nb+i != len(doc)):
        i+=1
    list_pay.append(doc[cur_nb+18:len(doc)-1])

data = {'Name':list_name,'Type':list_type, 'Speciality':list_spe,'Address':list_adr,'City':list_cit,'Postal_Code':list_post_cod, 'Payment_accepted':list_pay}
df = pd.DataFrame(data)
display(df)
# Out:
#                                                    Name       Type  \
# 0                                          Katia SEBBAN  Physician
# 1                   Centre médical Réaumur - CPAM Paris   Hospital
# 2                                            Sven THILL  Physician
# 3                                          Simon OHAYON  Physician
# 4                                     Amélie Aïm-Eusébi  Physician
# ...                                                 ...        ...
# 4746  Centre municipal et universitaire de santé Arc...   Hospital
# 4747                         Bodosahondra ANDRIAMANJATO  Physician
# 4748                                      Lena LANGLOIS  Physician
# 4749                            Delphine LAW-TO-LAGASSE  Physician
# 4750                                   Tassadit Dahmoun  Physician
#
#                       Speciality                       Address  \
# 0            Médecin généraliste                        178 Bi
# 1     Centre médical et dentaire               106 Rue Réaumur
# 2            Médecin généraliste              77 Rue Pelleport
# 3            Médecin généraliste            33 Rue du Ranelagh
# 4            Médecin généraliste             186 Boulevard Ney
# ...                          ...                           ...
# 4746             Centre de santé           3 Rue du 8 Mai 1945
# 4747         Médecin généraliste  15 Avenue Georges Clemenceau
# 4748         Médecin généraliste       9 Rue Jacques Margottin
# 4749         Médecin généraliste            6 Avenue de Verdun
# 4750         Médecin généraliste            6 Avenue de Verdun
#
#                 City Postal_Code          Payment_accepted
# 0              Paris       75020  Cash, Check, Credit card
# 1              Paris       75002  Cash, Check, Credit card
# 2              Paris       75020  Cash, Check, Credit card
# 3              Paris       75016  Cash, Check, Credit card
# 4              Paris       75018  Cash, Check, Credit card
# ...              ...         ...                       ...
# 4746         Arcueil       94110
# 4747          Sceaux       92330  Cash, Check, Credit card
# 4748  Bourg-la-Reine       92340  Cash, Check, Credit card
# 4749       Montrouge       92120  Cash, Check, Credit card
# 4750       Montrouge       92120  Cash, Check, Credit card
#
# [4751 rows x 7 columns]

# %% [markdown]
# ### Export the Data

# %%
df.to_csv(r"Dataframe-Generalist.csv", index=False)
